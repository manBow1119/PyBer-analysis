# %%
# %matplotlib notebook

# %% [markdown]
# # Bike Trippin
#
# For this assignment, you will be taking "Cycle Share" data from Seattle and creating charts to determine which gender borrows and uses bikes more often.
#
# * Import your dependencies and then import your data into a pandas data frame from the CSV within the 'Data' folder
# * Split up your data into groups based upon the gender column
#     * NOTE: There will be a garbage row with a gender of 'stoptime' which you will have to remove!
# * Chart your data using a bar graph, giving it both a title and labels for the axes

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

file_to_load = pd.read_csv("Resources/trip.csv")
file_to_load
bike_data_df = file_to_load
bike_data_df
# Out:
# /Users/e140563/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                 stoptime    bikeid  tripduration  \
# 0       10/13/2014 10:48  SEA00298       985.935
# 1       10/13/2014 10:48  SEA00195       926.375
# 2       10/13/2014 10:48  SEA00486       883.831
# 3       10/13/2014 10:48  SEA00333       865.937
# 4       10/13/2014 10:49  SEA00202       923.923
# ...                  ...       ...           ...
# 286853   8/31/2016 23:45  SEA00201       679.532
# 286854     9/1/2016 0:20  SEA00247      1965.418
# 286855     9/1/2016 0:20  SEA00300      1951.173
# 286856     9/1/2016 0:20  SEA00047      1883.299
# 286857     9/1/2016 0:20  SEA00442      1896.031
#
#                              from_station_name  \
# 0                          2nd Ave & Spring St
# ...

# %%
bike_data_df.drop(bike_data_df[bike_data_df["gender"]=="stoptime"])
gender_trips = bike_data_df["gender"].value_counts()
gender_trips
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-13366aa876d3> in <module>
# ----> 1 bike_data_df.drop(bike_data_df[bike_data_df["gender"]=="stoptime"])
#       2 gender_trips = bike_data_df["gender"].value_counts()
#       3 gender_trips
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
gender_trips.plot(kind="bar")
plt.bar(gender_trips)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Bonus!
#
# You will now take the same base data frame before and create some code that will allow you to create individual pie charts for each bike. For this part of the activity, we want you to chart the total 'Trip Duration' of each bike, sorted by gender. Bonus points if you can come up with a method to do this without using loc or iloc to filter the original data frame! You can use loc to filter group data though.
